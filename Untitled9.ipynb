# %%
import pandas as pd
import numpy as np
df= pd.read_csv("/content/train.csv",delimiter=";")
df['Age']=df['Age'].fillna(df['Age'].mean())
df.isnull().sum()
df["Cabin"].fillna('G6',inplace=True)
df
df_female=df.copy()
df_femaleNo=df.copy()
df_male=df.copy()
df_maleNo=df.copy()
df
# Out:
#      PassengerId Survived  Pclass  ...     Fare  Cabin  Embarked
# 0            343       No       2  ...  13.0000     G6         S
# 1             76       No       3  ...   7.6500  F G73         S
# 2            641       No       3  ...   7.8542     G6         S
# 3            568       No       3  ...  21.0750     G6         S
# 4            672       No       1  ...  52.0000    B71         S
# ..           ...      ...     ...  ...      ...    ...       ...
# 886           10      Yes       2  ...  30.0708     G6         C
# 887           61       No       3  ...   7.2292     G6         C
# 888          535       No       3  ...   8.6625     G6         S
# 889          102       No       3  ...   7.8958     G6         S
# 890          428      Yes       2  ...  26.0000     G6         S
#
# [891 rows x 12 columns]

# %%
df_male.drop(df_male[df_male['Sex']=='female'].index, inplace=True)
df_male.drop(df_male[df_male['Survived']=='Yes'].index, inplace=True)
print(df_male.shape)
# Out:
# (468, 12)

# %%
"those who did'nt survive"
import seaborn as sns
import matplotlib.pyplot as plt
g=sns.FacetGrid(df_male,col='Sex')
g.map(plt.hist,'Age')
plt.show()

# %%
df_maleNo.drop(df_maleNo[df_maleNo['Sex']=='female'].index, inplace=True)
df_maleNo.drop(df_maleNo[df_maleNo['Survived']=='No'].index, inplace=True)
df_maleNo
# Out:
#      PassengerId Survived  Pclass  ...      Fare Cabin  Embarked
# 19           225      Yes       1  ...   90.0000   C93         S
# 22           544      Yes       2  ...   26.0000    G6         S
# 26           588      Yes       1  ...   79.2000   B41         C
# 27           661      Yes       1  ...  133.6500    G6         S
# 37           431      Yes       1  ...   26.5500   C52         S
# ..           ...      ...     ...  ...       ...   ...       ...
# 824          829      Yes       3  ...    7.7500    G6         Q
# 841          513      Yes       1  ...   26.2875   E25         S
# 848          822      Yes       3  ...    8.6625    G6         S
# 856          184      Yes       2  ...   39.0000    F4         S
# 863          858      Yes       1  ...   26.5500   E17         S
#
# [109 rows x 12 columns]

# %%
"those who did survive"
import seaborn as sns
import matplotlib.pyplot as plt
g=sns.FacetGrid(df_maleNo,col='Sex')
g.map(plt.hist,'Age')
plt.show()

# %%
df_female.drop(df_female[df_female['Sex']=='male'].index, inplace=True)
df_female.drop(df_female[df_female['Survived']=='No'].index, inplace=True)
df_female
# Out:
#      PassengerId Survived  Pclass  ...     Fare Cabin  Embarked
# 7            382      Yes       3  ...  15.7417    G6         C
# 9            433      Yes       2  ...  26.0000    G6         S
# 12           755      Yes       2  ...  65.0000    G6         S
# 20            83      Yes       3  ...   7.7875    G6         Q
# 24           273      Yes       2  ...  19.5000    G6         S
# ..           ...      ...     ...  ...      ...   ...       ...
# 879          275      Yes       3  ...   7.7500    G6         Q
# 880          360      Yes       3  ...   7.8792    G6         Q
# 882          775      Yes       2  ...  23.0000    G6         S
# 886           10      Yes       2  ...  30.0708    G6         C
# 890          428      Yes       2  ...  26.0000    G6         S
#
# [233 rows x 12 columns]

# %%
df_femaleNo.drop(df_femaleNo[df_femaleNo['Sex']=='male'].index, inplace=True)
df_femaleNo.drop(df_femaleNo[df_femaleNo['Survived']=='Yes'].index, inplace=True)
df_femaleNo
# Out:
#      PassengerId Survived  Pclass  ...     Fare Cabin  Embarked
# 3            568       No       3  ...  21.0750    G6         S
# 11           294       No       3  ...   8.8500    G6         S
# 29           115       No       3  ...  14.4583    G6         C
# 43            72       No       3  ...  46.9000    G6         S
# 61           639       No       3  ...  39.6875    G6         S
# ..           ...      ...     ...  ...      ...   ...       ...
# 850          236       No       3  ...   7.5500    G6         S
# 860          206       No       3  ...  10.4625    G6         S
# 867          737       No       3  ...  34.3750    G6         S
# 876          375       No       3  ...  21.0750    G6         S
# 888          535       No       3  ...   8.6625    G6         S
#
# [81 rows x 12 columns]

# %%
"those who did'nt survive"
import seaborn as sns
import matplotlib.pyplot as plt
g=sns.FacetGrid(df_femaleNo,col='Sex')
g.map(plt.hist,'Age')
plt.show()

# %%
"those who survived"
import seaborn as sns
import matplotlib.pyplot as plt
g=sns.FacetGrid(df_female,col='Sex')
g.map(plt.hist,'Age')
plt.show()

# %%
plt.title("histogram of ages")
plt.xlabel("Age")
df['Age'].plot.hist()

# %%
import seaborn as sns
g=sns.FacetGrid(df,col='Sex')
g.map(plt.hist,'Age')
plt.show()

# %%
import seaborn as sns
g=sns.FacetGrid(df,col='Sex')
g.map(plt.hist,'Survived')
plt.show()

# %%
g=sns.FacetGrid(df,col='Survived')
g.map(plt.hist,'Cabin')
plt.show()

# %%
g=sns.FacetGrid(df,col='Survived')
g.map(plt.hist,'Pclass')
plt.show()

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map(df)

# %%
df[["Pclass", "Survived","PassengerId"]].groupby(["Survived","Pclass"], as_index=True).mean()
# Out:
#                  PassengerId
# Survived Pclass
# No       1        410.300000
#          2        452.123711
#          3        453.580645
# Yes      1        491.772059
#          2        439.080460
#          3        394.058824

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess":  "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
def getindex(txt,i):
    for j in range(len(txt)):
        if txt[j] == i:
            return j
    return -1

def clean(txt):
    newtxt =''
    for i in range(len(txt)):
        if txt[i] != " ":
            newtxt += txt[i]
    return newtxt
T = []
for i in (df['Name']):
    start = getindex(i,',')
    end = getindex(i,'.')
    txt = i[start+1:end]
    txt = clean(txt)
    T.append(txt)

# %%
T2 =[]
print(len(T))
for i in range(len(T)):
    for k, v in Title_Dictionary.items():
        if T[i] == k :
            T2.append(v)
print(len(T),"/",len(T2))
T2.append('Mrs')
print(df['Name'].shape)
df["Title"] = T2
df
df.drop(['Name'], axis=1)
# Out:
# 891
# 891 / 890
# (891,)
#      PassengerId Survived  Pclass     Sex  ...     Fare  Cabin  Embarked Title
# 0            343       No       2    male  ...  13.0000     G6         S   Mrs
# 1             76       No       3    male  ...   7.6500  F G73         S   Mrs
# 2            641       No       3    male  ...   7.8542     G6         S   Mrs
# 3            568       No       3  female  ...  21.0750     G6         S   Mrs
# 4            672       No       1    male  ...  52.0000    B71         S   Mrs
# ..           ...      ...     ...     ...  ...      ...    ...       ...   ...
# 886           10      Yes       2  female  ...  30.0708     G6         C   Mrs
# 887           61       No       3    male  ...   7.2292     G6         C  Miss
# 888          535       No       3  female  ...   8.6625     G6         S   Mrs
# 889          102       No       3    male  ...   7.8958     G6         S  Miss
# 890          428      Yes       2  female  ...  26.0000     G6         S   Mrs
# ...
